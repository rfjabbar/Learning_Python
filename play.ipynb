# %%
import math

# %% [markdown]
# <br> LaTex play around - have to do in MARKDOWN CELL
# <br> align equation to the left
# <br>
# <br>$P(A)=\frac{n(A)}{n(U)}$

# %% [markdown]
# <br> LaTex play around - have to do in MARKDOWN CELL
# <br> in the center with two money signs
# <br>
# <br>$$P(A)=\frac{n(A)}{n(U)}$$

# %% [markdown]
# Use \limits for \lim, \sum and \int to add limits to the top and bottom of each sign
# <br>
# <br>Use a backslash to escape LaTeX special words as as math symbols, Latin words, text, etc.
# <br>
# <br> table shows basic LaTeX commands:
# <br>
# ![image.png](attachment:image.png)

# %%
import jupyterthemes as jt

# %%
jt -t onedork -fs 12.5 -nfs 15 -dfs 11 -cellw 88% -altp -ofs 11 -T -N
# Out:
#   File "<ipython-input-2-e667bcf30a8a>", line 1
#     jt -t onedork -fs 12.5 -nfs 15 -dfs 11 -cellw 88% -altp -ofs 11 -T -N
#                 ^
# SyntaxError: invalid syntax
