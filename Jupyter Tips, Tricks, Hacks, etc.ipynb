# %% [markdown]
# This will be a collection of tips, tricks, hacks, how-tos, etc for using Jupyter Notebook. This will include information from a variety of sources.

# %% [markdown]
# # 'Hands-On Jupyter Notebook Hacks'
# <br>
# <br>Author: <b>Shinichi Okada</b></br>
#
# <br>
# <br> link: <a>https://towardsdatascience.com/hands-on-jupyter-notebook-hacks-f59f313df12b</a>

# %% [markdown]
# ## Gist
# <br>
# <br> Used to share snippets hosted by Github. <i>Going to skip this - not interested right now</i>

# %% [markdown]
# ## display() over print() for dataFrame

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df = pd.DataFrame(
    [
        [48,22,33,47],
        [35,36,42,27]
    ],
    index=["Male", "Female"],
    columns=["Black","White","Red","Blue"])

print(df)
display(df)
df
# Out:
#         Black  White  Red  Blue
# Male       48     22   33    47
# Female     35     36   42    27
#         Black  White  Red  Blue
# Male       48     22   33    47
# Female     35     36   42    27
#         Black  White  Red  Blue
# Male       48     22   33    47
# Female     35     36   42    27

# %% [markdown]
# ## Output without print()
# <br>
# Can use to print() for all outputs - "if you feel too lazy.."

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# test this
testvar = 2
testvar
testvar
# Out:
# 2
# 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Useful Shortcuts

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 'Productivity Tips for Jupyter Users'
# <br>
# <br>Author: <b>Shinichi Okada</b></br>
#
# <br>
# <br> link: <a>https://towardsdatascience.com/stepping-into-intermediate-with-jupyter-f6647aeb1184</a>

# %% [markdown]
# ## Startup Files

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
